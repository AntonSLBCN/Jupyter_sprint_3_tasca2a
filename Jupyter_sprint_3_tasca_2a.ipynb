# %% [markdown]
# # <span style=color:darkblue><ins>Tasca 2-A: Estructura de una Matriu<ins></span>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os 
import matplotlib.image as mpimg

# %% [markdown]
# ## <span style=color:green><ins>Exercici 1 Tasca 2A</ins></span>

# %% [markdown]
# Crea un np.array de una dimension, que inclogui l'almenys 8 nombres sencers, data type int64. Mostra la dimensió i la forma de la matriu.

# %%
myarray = np.random.randint(20, size= 8, dtype=np.int64)
print( myarray.dtype ,' y ', type(myarray))
# Out:
# int64  y  <class 'numpy.ndarray'>

# %%
print('Array format per ' + str(myarray.ndim)+ ' dimensions')
# Out:
# Array format per 1 dimensions

# %%
print (' La matriu es ' ,  myarray)
# Out:
#  La matriu es  [ 6  0  2 18 15 11 11 17]

# %%
plt.plot (myarray)

# %% [markdown]
# ## <span style=color:green><ins>Exercici 2 Tasca 2A</ins></span>

# %% [markdown]
# De la matriu de l'exercici 1, calcula el valor mitjà dels valors introduïts i resta la mitjana resultant de cada un dels valors de la matriu.

# %%
#calcular la mitja del la matriu
vmedio= myarray.mean()
int(vmedio)
# Out:
# 10

# %%
#Resta de la mitjana de cada un dels valors de la matriu.
np.subtract(myarray,vmedio)
# Out:
# array([ -4., -10.,  -8.,   8.,   5.,   1.,   1.,   7.])

# %% [markdown]
# ## <span style=color:green><ins>Exercici 3 Tasca 2A</ins></span>

# %% [markdown]
# Crea una matriu bidimensional amb una forma de 5 x 5. Extreu el valor màxim de la matriu, i els valors màxims de cadascun dels seus eixos.

# %%
myarray = np.random.randint(10, size=(2,5), dtype=np.int64)
myarray
# Out:
# array([[1, 4, 4, 5, 2],
#        [7, 2, 0, 5, 5]], dtype=int64)

# %%
#Valor maxim d'una matriu amb la funcion .max()
myarray.max()
# Out:
# 7

# %%
print( 'El valor màxim del la primera dimensió es ', str(max(myarray[0])),' i de la segona ', str(max(myarray[1])))
# Out:
# El valor màxim del la primera dimensió es  5  i de la segona  7

# %% [markdown]
# ## <span style=color:green><ins>Exercici 4 Tasca 2A</ins></span>

# %% [markdown]
# Mostreu-me amb exemples de diferents matrius, la regla fonamental de Broadcasting que diu : "les matrius es poden transmetre / broadcast.entre si les seves dimensions coincideixen o si una de les matrius té una mida d'1".

# %%
#Primer exemple
matrix = np.array([1,2,2])
matrix1 = np.array([1,1,1])
matrixSum = matrix + matrix1
print(matrixSum)
# Out:
# [2 3 3]

# %%
#Exemple 1
xa = np.array([1,2,2])
xb = np.array([10])
xsum = xa + xb
print(xsum)
# Out:
# [11 12 12]

# %%
#Exemple 2
x= np.array([[4, 1, 2],[8, 8, 5],[3, 7, 6]])
y = np.array([[1],[1],[1]])
z = np.array([2, 2, 2])

# %%
#Exemple 2
h = x + y
h
# Out:
# array([[5, 2, 3],
#        [9, 9, 6],
#        [4, 8, 7]])

# %%
#Exemple 3
H = x + y - z
H
# Out:
# array([[3, 0, 1],
#        [7, 7, 4],
#        [2, 6, 5]])

# %% [markdown]
# ## <span style=color:green><ins>Exercici 5 Tasca 2A</ins></span>

# %% [markdown]
# Utilitza la Indexació per extreure els valors d'una columna i una fila de la matriu. I suma els seus valors.

# %%
arr = np.random.randint(10, size=(5,5), dtype=np.int64)
arr
# Out:
# array([[8, 0, 8, 7, 7],
#        [4, 7, 2, 1, 0],
#        [3, 4, 4, 6, 6],
#        [5, 0, 5, 6, 4],
#        [5, 7, 4, 5, 6]], dtype=int64)

# %%
#extracció del la fila
r = arr[3, 0:5]
r
# Out:
# array([5, 0, 5, 6, 4], dtype=int64)

# %%
#Extracció de la columna
c= arr[0:5,4]
c
# Out:
# array([7, 0, 6, 4, 6], dtype=int64)

# %%
t = r + c
t
# Out:
# array([12,  0, 11, 10, 10], dtype=int64)

# %% [markdown]
# ## <span style=color:green><ins>Exercici 6 Tasca 2A</ins></span>

# %% [markdown]
# Mask la matriu anterior, realitzeu un càlcul booleà vectoritzat, agafant cada element i comprovant si es divideix uniformement per quatre.
#
# Això retorna una matriu de mask de la mateixa forma amb els resultats elementals del càlcul.

# %%
df = pd.DataFrame(arr)
df
# Out:
#    0  1  2  3  4
# 0  8  0  8  7  7
# 1  4  7  2  1  0
# 2  3  4  4  6  6
# 3  5  0  5  6  4
# 4  5  7  4  5  6

# %%
df1 = df.mask(df%4 == 0, True)
df1
# Out:
#       0     1     2  3     4
# 0  True  True  True  7     7
# 1  True     7     2  1  True
# 2     3  True  True  6     6
# 3     5  True     5  6  True
# 4     5     7  True  5     6

# %%
df1.loc[1,1]
# Out:
# 7

# %% [markdown]
# ## <span style=color:green><ins>Exercici 7 Tasca 2A</ins></span>

# %% [markdown]
# A continuació, utilitzeu aquesta màscara per indexar a la matriu de números original. Això fa que la matriu perdi la seva forma original,
#
# reduint-la a una dimensió, però encara obteniu les dades que esteu cercant.

# %%
for x in range(len(df1)):
    for y in range(len(df1[x])):
        if df1.loc[x,y] == True:
            df1.loc[x,y]= df.loc[x,y]
#no estic segur d'haver contestat.

# %%
df
# Out:
#    0  1  2  3  4
# 0  8  0  8  7  7
# 1  4  7  2  1  0
# 2  3  4  4  6  6
# 3  5  0  5  6  4
# 4  5  7  4  5  6

# %%
df1
# Out:
#    0  1  2  3  4
# 0  8  0  8  7  7
# 1  4  7  2  1  0
# 2  3  4  4  6  6
# 3  5  0  5  6  4
# 4  5  7  4  5  6

# %% [markdown]
# ## <span style=color:green><ins>Exercici 7 Tasca 2A</ins></span>

# %% [markdown]
# Manipulació d’imatges amb Matplotlib.
#
# Carregareu qualsevol imatge (jpg, png ..) amb Matplotlib. adoneu-vos que les imatges RGB (Red, Green, Blue) són realment només amplades × alçades × 3 matrius (tres canals Vermell, Verd i Blau), una per cada color de nombres enters int8,
#
# manipuleu aquests bytes i torneu a utilitzar Matplotlib per desar la imatge modificada un cop hàgiu acabat.
#
# Ajuda:Importeu, import matplotlib.image as mpimg. estudieu el metodde mpimg.imread(()Mostreu-me a veure que passa quan eliminem el canal G Verd o B Blau.
#
# Mostreu-me a veure que passa quan eliminem el canal G Verd o B Blau. Hauries de utizar la indexacion per selecciones el canal que voleu anul·lar.
#
# Utilitzar el mètode, mpimg.imsave () de la llibreria importada, per guardar les imatges modificades i que haureu de pujar al vostre repositori a github.

# %% [markdown]
# * Matplotlib — plt.imread()
# * OpenCV — cv2.imread()
# * Pillow — Image.open()
# * scikit-image — io.imread()

# %%
mypath = 'C:\\Users\Anton SL\\OneDrive\\Documentos\\IT_Academics\\Data_Science\\Jupyter_sprint_3_tasca2a\\castillo.jpg'
img = mpimg.imread(mypath)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
#dimensiones de la imagen
img.shape
# Out:
# (1536, 2048, 3)

# %%
#copiat de la web però no ho entenc????
plt.imshow(img[:,:,0],vmin=0,vmax=1)
plt.title("Canal Rojo")
plt.figure()
plt.imshow(img[:,:,1],vmin=0,vmax=1)
plt.title("Canal Verde")
plt.figure()
plt.imshow(img[:,:,2],vmin=0,vmax=1)
plt.title("Canal Azul")
# Out:
# Text(0.5, 1.0, 'Canal Azul')

# %%
img_blue=np.copy(img) # copia imatge 
img_blue[:,:,0]=0
plt.title("Blau")
plt.imshow(img_blue)
mpimg.imsave('img_blau.png', img_blue, format='png' )

# %%
img_red=np.copy(img) 
img_red[:,:,1]=0
plt.title("Vermell")
plt.imshow(img_red)
mpimg.imsave('img_red.png', img_red, format='png' )

# %%
img_yellow=np.copy(img) 
img_yellow[:,:,2]=0
plt.title("Grog")
plt.imshow(img_yellow)
mpimg.imsave('img_yellow.png', img_yellow, format='png' )
